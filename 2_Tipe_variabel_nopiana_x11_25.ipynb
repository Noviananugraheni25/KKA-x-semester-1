# %% [markdown]
# <a href="https://colab.research.google.com/github/Noviananugraheni25/KKA-x-semester-1/blob/main/2_Tipe_variabel_nopiana_x11_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Noviana rizki n
#
# No. absen :25
#
# kelas :x11

# %% [markdown]
# ##konsep data variabel

# %%
email_user_1 Fatir
fatir
# Out:
#   File "/tmp/ipython-input-1272526572.py", line 1
#     email_user_1 Fatir
#                  ^
# SyntaxError: invalid syntax

# %%
#single assignment
nama_mahasiswa_1 = "Alexandrio"

print(nama_mahasiswa_1)
# Out:
# Alexandrio

# %% [markdown]
# ##Assigmen

# %%
#Single assignment
nama_mahasiswa_1 = "Alexandria"


print(nama_mahasiswa_1)
# Out:
# Alexandria

# %%
#multipe assignment

#nama_barang_1= "tahu"
#nama_barang_2 ="tempe"

nama_barang_1, nama_barang_2 = "tahu", " tempe"


print(nama_barang_1)
print(nama_barang_2)
# Out:
# tahu
#  tempe

# %%
#assigment yang sama
nilai_devandra = nilai_willy= nilai_dzaki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzaki)
# Out:
# 100
# 100
# 100

# %%
#Menimpa/Mengubah nilai variabel

nilai_himam =95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam =100

# %%
print(nilai_himam)
# Out:
# 100

# %% [markdown]
# ##Operator Aritmatika

# %%
buku_tulis_himam = 55
buku_tukis_vico = 15

# %%
#Penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# 70

# %%
#Pengurangan

selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisi_buku_tulis)
# Out:
# 40

# %%
#Perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus
print(total_buku_tulis)
# Out:
# 30

# %%
#Pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#Pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#Sisa bagi
sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# 3

# %%
#Perpangkatan
sisi = 5

luas_persegi = sisi ** 2
print(luas_persegi)
# Out:
# 25

# %%
luas_persegi ** (1/2)
print(sisi)
# Out:
# 5

# %% [markdown]
# ##Peggunaan Operator di Phyton

# %%
#Tanpa variabel
print(20+3)
# Out:
# 23

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi disimpan ke dalam variabel
Jumlah_roti_swiss = 20+3

print(Jumlah_roti_swiss)
# Out:
# 23

# %%
 #Hasil operasi disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

jumlan_roti_swiss = roti_swiss_alex + roti_swiss_nazril
print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# #Tipe variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72,5

type(berat_badan)
# Out:
# tuple

# %%
nama = "dzaki"

type(nama)
# Out:
# str

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_kordinat =-5
type(titik_kordinat)
# Out:
# int

# %% [markdown]
# ##Konversi  tipe data

# %%
usia= 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia=float (usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan= int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia =7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia =str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus=1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print = (lulus)
type (lulus)
# Out:
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3646064215.py in <cell line: 0>()
#       1 lulus = 0
# ----> 2 print(lulus)
#       3 type(lulus)
#
# TypeError: 'bool' object is not callable
