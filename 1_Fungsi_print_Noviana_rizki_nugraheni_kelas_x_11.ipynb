# %% [markdown]
# <a href="https://colab.research.google.com/github/Noviananugraheni25/KKA-x-semester-1/blob/main/1_Fungsi_print_Noviana_rizki_nugraheni_kelas_x_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : noviana rizki nugraheni
#
# kelas:x11
#
# No absen:25

# %% [markdown]
# ##Menampilkan teks bebas

# %%
print("noviana rizki nugraheni")
# Out:
# noviana rizki nugraheni

# %%
print("jenis blackpink")
# Out:
# jenis blackpink

# %% [markdown]
# ##Menampilkan nilai variabel

# %%
nama_saudara="ayu Rusli"
print(nama_saudara)
# Out:
# ayu Rusli

# %%
jumlah_saudara=3
print(jumlah_saudara)
# Out:
# 3

# %%
nama_idola = "rafi ahamad"
print (nama_idola)
print ("nama_idola")
# Out:
# rafi ahamad
# nama_idola

# %% [markdown]
# ##Menampilkan  teks bebas dan nilai varianel

# %% [markdown]
# ##Menampilkan teks bebas dan nilai variabel Menggunakan tanda koma

# %%
print ("saya memiliki saudara sebanyak ", nama_saudara)
# Out:
# saya memiliki saudara sebanyak  ayu Rusli

# %% [markdown]
# ##Menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %% [markdown]
# ##Menampilkan teks bebas dan nilai variabel menggunakan f string

# %% [markdown]
# ##escape carakter

# %%
print("Nama: noviana rizki nugraheni")
print("Kelas: X. 11")
print("No.Absen:25")
# Out:
# Nama: noviana rizki nugraheni
# Kelas: X. 11
# No.Absen:25

# %%
print (f"saya memiliki saudara sebanyak{jumlah_saudara}.Nama saudara saya adalah{nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak3.Nama saudara saya adalahayu Rusli.

# %%
print("Nama:Noviana rizki nugraheni\nkelas: x 11\nNo. Absen:29")
# Out:
# Nama:Noviana rizki nugraheni
# kelas: x 11
# No. Absen:29

# %%
print ('Noviana rizkinugraheni')
# Out:
# Noviana rizkinugraheni

# %%
print('rafi ahamad')
# Out:
# rafi ahamad

# %%
print('rafi halilintar')
# Out:
# rafi halilintar

# %%
print('Bu sinta berkata, "Harap fokus menyimak! ".')
# Out:
# Bu sinta berkata, "Harap fokus menyimak! ".

# %%
print("lokasi penyimpanan tugas KkA di D:\MAN Demak\\MAN Demak \\ KKA\\Tugas ")
# Out:
# lokasi penyimpanan tugas KkA di D:\MAN Demak\MAN Demak \ KKA\Tugas
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# /tmp/ipython-input-913069199.py:1: SyntaxWarning: invalid escape sequence '\M'
#   print("lokasi penyimpanan tugas KkA di D:\MAN Demak\\MAN Demak \\ KKA\\Tugas ")

# %% [markdown]
# ## fungsi parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_3,nama_siswa_2,nama_siswa_1,nama_siswa_2,sep="_")
# Out:
# Haidar_Adzka_Daffanes_Adzka

# %%
nama_siswa_1 ="Daffanes"
nama_siswa_2 ="Adzka"
nama_siswa_3 ="Haidar"

print(nama_siswa_1, nama_siswa_2, sep="_")
# Out:
# Daffanes_Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end="_")
print(nama_siswa_2)
# Out:
# Daffanes_Adzka

# %% [markdown]
# #Latihan soal:
# #Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# #Haidar#Adzka#Daffanes#Adzka
